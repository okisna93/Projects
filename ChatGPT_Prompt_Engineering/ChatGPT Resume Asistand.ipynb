# %%
import openai
import os
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

openai.api_key ='API-KEY'

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
    model=model,
    messages=messages,
    temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

# %%
Input=f"""ISMET OKAN CELIK
Woodside, NY 11377 | 347.470.0718 | ismetokancelik@gmail.com | okisna93.github.io/iokan_web/

CAREER SUMMARY
Artificial Intelligence Engineer • Data Scientist • Machine Learning Engineer • Data Analyst
An accomplished Data Scientist and Data Analyst with a Master's degree in Applied Artificial Intelligence with experience working on projects in various domains such as healthcare, finance, and retail
Strong proficiency in machine learning algorithms and statistical analysis techniques, and Large Language Models (LLMs), with expertise in programming languages such as Python, C++, and SQL. Developed models for tumor detection, customer segmentation, recommendation systems, and natural language processing tasks using LLMs
Experience in data visualization and storytelling, creating interactive dashboards to presenting complex data insights to both technical and non-technical stakeholders, and collaborating with cross-functional teams to solve business problems
Proven ability to work in fast-paced environments and deliver projects within tight deadlines. Passionate about staying up-to-date with the latest research and trends in the field, and continuously improving skills through online courses and self-learning

AREAS OF EXPERTISE
 
Machine Learning
Data Collection & Processing
Data Visualization
Project Management
Process Improvement
Team building & Leadership
Cross-functional Collaboration
Key Relationships Development
Strategic Planning
 

EDUCATION
Master of Engineering, Applied Artificial Intelligence                                                              01/2023
Stevens Institute of Technology, Hoboken, NJ
Course Work: Applied Machine Learning, Deep Learning, Applied Modeling and Optimization, Big Data, Pattern Recognition, Engineering Programming: Python

Bachelor of Science, Mechanical Engineering                                                                             06/2016
Karadeniz Technical University, Trabzon, Turkey

PROFESSIONAL EXPERIENCE
Freelance, New York, NY	04/2022 – Present
Data Scientist/ Machine Learning Engineer
•	Conducted data analysis and developed predictive models for various clients in industries such as healthcare and finance
•	Worked closely with clients to understand business needs and translate into actionable data insights
•	Utilized Python programming language to extract, transform, and load (ETL) large datasets from various sources, including APIs, databases, and web scraping tools
•	Built machine learning models using algorithms such as random forests, logistic regression, and gradient boosting to predict outcomes and identify trends

Stevens Institute of Technology, Hoboken, NJ	10/2021 – 01/2023
Graduate Research Assistant
•	Conducted research on multiple machine learning projects, including a human face expression detection system, a store sales prediction model, a music recommendation system, and a brain tumor detection model
•	Utilized various data visualization techniques, such as Matplotlib, Seaborn, and Plotly to analyze and preprocess large datasets 
•	Developed and implemented a range of machine learning algorithms, including convolutional neural networks, ARIMA, custom regression, linear regression, XGBoost regression, matrix factorization, logistic regression, decision tree, random forest, gradient boosted tree, and ensemble learning algorithms
•	Programmed a face recognition algorithm using OpenCV library on Python and built a smart door system using Raspberry Pi to unlock the door upon detecting registered faces

Bahar Water Treatment Systems, Tekirdag, Turkey	08/2017 – 07/2018
The company provides water and wastewater treatment solutions, and environmental consultancy services, and produces machinery and equipment from stainless and carbon steel.
Project Engineer
•	Delivered 10 projects to clients, each one meeting or exceeding expectations, and reduced the error rate by 20%, resulting in higher client satisfaction and reduced costs associated with rework
•	Spearheaded all planning, production, and delivery phases on projects with budgets ranging from $112.5K to $1.1M
•	Generated a total of $500,000 in revenue through these projects, representing a significant contribution to the company's bottom line
•	Formulated and implemented project plans, including schedules and resource allocation for seamless functionality
•	Tracked project deliverables by composing and presenting project reports, including status updates and budget reports

Bahar Water Treatment Systems, Tekirdag, Turkey	02/2017 – 08/2017
Production Engineer
•	Trained and supervised production staff to enhance workforce capacity
•	Collaborated with other departments, such as engineering and quality control to establish beneficial alliances
•	Assessed and monitored projects to raise the value, increase cost, and improve quality as much as possible
•	Reduced material waste by 5% and increased efficiency by 15% by implementing new manufacturing procedures
•	Decreased errors by 10% and improved workflow efficiency by executing a new quality management system

TECHNICAL SKILLS
Operating Systems: Debian GNU/Linux, Windows, macOS
Programming: Python, C++, SQL, MATLAB
Data Analysis and Machine Learning tools: NumPy, Pandas, SciPy, Scikit-learn, TensorFlow, Keras
Data Visualization: Matplotlib, Seaborn, Plotly, Folium, Tableau
Other: Git, Jupyter Notebook, Anaconda, Microsoft Office Suite, Data Mining, Data Wrangling, Web Scraping, OpenCV, Large Language Models (LLMs), AWS (Amazon Web Services), IBM Cloud, Google Cloud Platform (GCP), Spark, Hadoop, 

CERTIFICATIONS
Data Visualization with Python – Coursera (IBM), 2023
Data Analysis with Python – Coursera (IBM) ,2023
Databases and SQL for Data Science with Python – Coursera (IBM) ,2023
Python Project for Data Science – Coursera (IBM) ,2023
Data Science Methodology – Coursera (IBM) ,2023
Python for Data Science, AI & Development – Coursera (IBM) ,2023
Tools for Data Science – Coursera (IBM) ,2023
Data Science Orientation – Coursera (IBM), 2023 
Learning Java Applications – Linkedln, 2022
Learning Java – Linkedln, 2022 
OpenCV for Python Developers – Linkedln, 2021
Git Essential Training: The Basics – Linkedln, 2021

LANGUAGES
Turkish & English
"""

# %%
JobPost1=f"""You won’t simply present data, but tell data-driven stories. You will convince and influence your partners using clear insights and recommendations. You will build credibility through structure and clarity, and be a trusted strategic partner.

Data Scientist, Product Analytics Responsibilities:

Work with large and complex data sets to solve a wide array of challenging problems using different analytical and statistical approaches.
Apply technical expertise with quantitative analysis, experimentation, data mining, and the presentation of data to develop strategies for our products that serve billions of people and hundreds of millions of businesses.
Identify and measure success of product efforts through goal setting, forecasting, and monitoring of key product metrics to understand trends.
Define, understand, and test opportunities and levers to improve the product, and drive roadmaps through your insights and recommendations.
Partner with Product, Engineering, and cross-functional teams to inform, influence, support, and execute product strategy and investment decisions.

Minimum Qualifications:

Bachelor's degree in Mathematics, Statistics, a relevant technical field, or equivalent practical experience.
A minimum of 2 years of work experience in analytics (minimum of 1 years with a Ph.D.)
Experience with data querying languages (e.g. SQL), scripting languages (e.g. Python), and/or statistical/mathematical software (e.g. R)

Preferred Qualifications:

Masters or Ph.D. Degree in a quantitative field. """

# %%
JobPost2=f"""
Bachelor's degree in Computer Science, Mathematics, a related technical field, or equivalent practical experience.
3 years of experience building or leveraging machine learning solutions and developing applications utilizing AI frameworks and methods.
Experience in performing technical presentations or public speaking.

Preferred qualifications:

Experience architecting and developing software or infrastructure for scalable, distributed systems.
Experience in and understanding of data and information management, as it relates to big data trends and issues within businesses.
Experience with complex customer’s existing software workloads, and the ability to define a technical migration roadmap to the Cloud reflecting specific customer needs.

About The Job

The Google Cloud Platform team helps customers transform and build what's next for their business — all with technology built in the cloud. Our products are engineered for security, reliability and scalability, running the full stack from infrastructure to applications to devices and hardware. Our teams are dedicated to helping our customers — developers, businesses, educational institutions and government agencies — see the benefits of our technology come to life. As part of an entrepreneurial team in this rapidly growing business, you will play a role in understanding the needs of our customers and help shape the future of businesses of all sizes use technology to connect with customers, employees, and partners.

As an Enterprise Customer Engineer, you will support Google Cloud Sales teams and lead roadmaps, missions, and strategy solutions. You'll meet with customers to facilitate business transformations, success patterns, and establish architectural blueprints for the migration to Google Cloud.

In this role, you'll identify and assess customer artificial intelligence (AI) or machine learning (ML) opportunities to uncover cloud solutions to recommend, plan for, and address core market opportunities and use cases. You will enable customers, partners, and field teams on the best way to position solutions on Google Cloud, explain technical features, and problem-solve potential roadblocks.

Google Cloud accelerates organizations’ ability to digitally transform their business with the best infrastructure, platform, industry solutions and expertise. We deliver enterprise-grade solutions that leverage Google’s cutting-edge technology – all on the cleanest cloud in the industry. Customers in more than 200 countries and territories turn to Google Cloud as their trusted partner to enable growth and solve their most critical business problems.

The US base salary range for this full-time position is $130,000-$194,000 + bonus + equity + benefits. Our salary ranges are determined by role, level, and location. The range displayed on each job posting reflects the minimum and maximum target for new hire salaries for the position across all US locations. Within the range, individual pay is determined by work location and additional factors, including job-related skills, experience, and relevant education or training. Your recruiter can share more about the specific salary range for your preferred location during the hiring process.

Please note that the compensation details listed in US role postings reflect the base salary only, and do not include bonus, equity, or benefits. Learn more about benefits at Google .

Responsibilities

Help prospective customers and partners understand the power of Google Cloud, technical features, design architectures, and problem-solve any potential roadblocks.
Lead the roadmap by advocating for enterprise customer requirements and needs.
Demonstrate the business value of Google Cloud AI or ML solutions.
Travel to customer sites and events as needed.
 """

# %%
JobPost3=f"""
Position Overview

As an AI/Client Engineer, you will be responsible for developing and implementing advanced analytics models and machine learning algorithms as part of our Innovation Team. You will collaborate with data scientists and other stakeholders to understand business needs and provide AI solutions. You will also contribute to our data infrastructure and work on scalable AI deployment.

Key Responsibilities
Develop, validate, and implement machine learning models and algorithms.
Collaborate with data scientists and other stakeholders to understand and define project goals.
Maintain data infrastructure and ensure scalability and efficiency of data-related operations.
Keep abreast of the latest developments in the field of AI/Client and recommend ways to implement them in our operations.
Communicate complex data findings in a clear and understandable manner to non-technical stakeholders.
Adhere to data privacy and security guidelines.
Participate in the entire AI project lifecycle, from concept to deployment and maintenance.
Qualifications
Bachelor's degree in Computer Science, Statistics, or related field; Master's or Ph.D. preferred.
Proven experience as an AI/Client Engineer or similar role.
Strong knowledge of machine learning frameworks (like PyTorch) and libraries (like scikit-learn).
An understanding specifically in the field of LLM's and libraries like LangChain / Semantic-Kernel.
Experience with data science tools (e.g., Python) and database languages (e.g., SQL).
Understanding of data structures, data modeling, and software architecture.
Proficiency in algorithm design, problem-solving, and complexity analysis.
Excellent communication skills.
Ability to work in a team.
Nice-to-haves
Knowledge of cloud services: Azure, Google Cloud, AWS.
Familiarity of Azure OpenAI Services, and various new features Microsoft is releasing.
Experience in natural language processing, computer vision, or other AI subfields. """

# %%
prompt = f"""
You are a Personal Resume service AI assistant.
Your task is to build a resume based on user input and conver that resume to better format which matches with job description.\
Given the user resume input delimited by ```, \
Given the three JobPost delimited by ```,\
Generate a resume with similar format to user input which highly matches with all three JobPost.\

List technical skills so the employers can easily find what is of most importance to
them and can quickly learn what user have done

Present information in the resume that relates to the employer
specifications for the position user seeks in the field

Write a resume that has FOCUS and is tailored to the position
Use the keywords in the job description in the resume bullet
points for a maximum match

Be consistent in the formatting for user education, experience, and date listings

Include a clear and concise career summary at the beginning of the resume. 
This section should provide an overview of the candidate's background, key skills, and notable achievements. 
Emphasize the candidate's expertise

Utilize bullet points to highlight key accomplishments and quantify results where possible. 
This can include metrics such as revenue generated, cost savings achieved, accuracy improvements, or efficiency gains. 
Emphasize the candidate's ability to work on diverse projects and collaborate with cross-functional teams.

Think of the resume you will create as a MARKETING document

Use clear and legible fonts, and proofread for any grammatical or spelling errors.

Format everything as HTML that can be used in a website.
Place the description in a <div> element.

Show the matching score of the resume with all tree JobPost at the end with this format:
Matching Score1:
Matching Score2:
Matching Score3:

User Resume Input: ```{Input}```
Job Post1: {JobPost1}
Job Post2: {JobPost2}
Job Post3: {JobPost3}
"""
response = get_completion(prompt)
print(response)

# %%
from IPython.display import display, HTML

# %%
display(HTML(response))
# Out:
# <div>
# <h1>ISMET OKAN CELIK</h1>
# <h3>Woodside, NY 11377 | 347.470.0718 | ismetokancelik@gmail.com | okisna93.github.io/iokan_web/</h3>
# <hr>
# <h2>CAREER SUMMARY</h2>
# <p>Artificial Intelligence Engineer • Data Scientist • Machine Learning Engineer • Data Analyst</p>
# <p>An accomplished Data Scientist and Data Analyst with a Master's degree in Applied Artificial Intelligence with experience working on projects in various domains such as healthcare, finance, and retail</p>
# <p>Strong proficiency in machine learning algorithms and statistical analysis techniques, and Large Language Models (LLMs), with expertise in programming languages such as Python, C++, and SQL. Developed models for tumor detection, customer segmentation, recommendation systems, and natural language processing tasks using LLMs</p>
# ...
